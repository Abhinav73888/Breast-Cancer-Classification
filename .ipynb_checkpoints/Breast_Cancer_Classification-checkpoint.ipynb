# %% [markdown]
# ## Importing required libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings 

warnings.filterwarnings('ignore')

# %% [markdown]
# ## Reading dataset

# %%
data = pd.read_csv('./data/data.csv')
data.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %% [markdown]
# ## Checking whether data is balanced or not

# %%
sns.countplot(data['diagnosis'])
plt.show()

# %% [markdown]
# ## Data cleaning

# %%
# dropping some unnecessary columns
data.drop(columns=['id', 'Unnamed: 32'], inplace=True)

# %%
# checking for null values
data.isna().sum()
# Out:
# diagnosis                  0
# radius_mean                0
# texture_mean               0
# perimeter_mean             0
# area_mean                  0
# smoothness_mean            0
# compactness_mean           0
# concavity_mean             0
# concave points_mean        0
# symmetry_mean              0
# fractal_dimension_mean     0
# radius_se                  0
# texture_se                 0
# perimeter_se               0
# area_se                    0
# smoothness_se              0
# compactness_se             0
# concavity_se               0
# concave points_se          0
# symmetry_se                0
# fractal_dimension_se       0
# radius_worst               0
# texture_worst              0
# perimeter_worst            0
# area_worst                 0
# smoothness_worst           0
# compactness_worst          0
# concavity_worst            0
# concave points_worst       0
# symmetry_worst             0
# fractal_dimension_worst    0
# dtype: int64

# %% [markdown]
# ## Data visualization

# %%
i = 1
plt.figure(figsize=(20,20))
for col in data.columns[1:10]:
    plt.subplot(3,3,i)
    sns.distplot(data[data['diagnosis']=='M'][col], label='M')
    sns.distplot(data[data['diagnosis']=='B'][col], label='B')
    plt.legend()
    i+=1

# %%
i = 1
plt.figure(figsize=(20,20))
for col in data.columns[10:19]:
    plt.subplot(3,3,i)
    sns.distplot(data[data['diagnosis']=='M'][col], label='M')
    sns.distplot(data[data['diagnosis']=='B'][col], label='B')
    plt.legend()
    i+=1

# %%
i = 1
plt.figure(figsize=(20,20))
for col in data.columns[19:28]:
    plt.subplot(3,3,i)
    sns.distplot(data[data['diagnosis']=='M'][col], label='M')
    sns.distplot(data[data['diagnosis']=='B'][col], label='B')
    plt.legend()
    i+=1

# %%
i = 1
plt.figure(figsize=(20,20))
for col in data.columns[28:]:
    plt.subplot(3,3,i)
    sns.distplot(data[data['diagnosis']=='M'][col], label='M')
    sns.distplot(data[data['diagnosis']=='B'][col], label='B')
    plt.legend()
    i+=1

# %% [markdown]
# **Observing the above distribution plots, some of the important features can be selected.**

# %%
reduced_data = data[['diagnosis', 'radius_mean', 'area_mean', 'concave points_mean', 'perimeter_mean', 'concavity_mean', 'area_se', 'perimeter_worst', 'radius_worst', 'concavity_worst', 'concave points_worst']]

# %% [markdown]
# ## Plotting the correlation map

# %%
plt.figure(figsize=(12,10))
sns.heatmap(reduced_data.corr(), annot=True, cmap='Blues')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Pair plot among highly correlated features

# %%
sns.pairplot(reduced_data[['radius_mean', 'area_mean', 'perimeter_mean']])

# %% [markdown]
# **Radius mean, area mean and perimeter mean are highly correlated so we can select just one among them.**

# %%
reduced_data.drop(columns=['area_mean', 'perimeter_mean'], inplace=True)

# %% [markdown]
# ## Data preprocessing

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import LabelEncoder

# encoding categorical to numeric
enc = LabelEncoder()
reduced_data['diagnosis'] = enc.fit_transform(reduced_data['diagnosis'])

# splitting data into features and labels
features = reduced_data.drop(columns=['diagnosis'])
labels = reduced_data['diagnosis']

# scaling features as SVM is range sensitive 
scaler = StandardScaler()
scaled_features = scaler.fit_transform(features)

# splitting data into train, test with ratio of 80-20
x_train, x_test, y_train, y_test = train_test_split(features, labels, test_size=0.2, random_state=42)

# %% [markdown]
# ## Applying SVM model for classification

# %%
from sklearn.svm import SVC

clf = SVC()
clf.fit(x_train, y_train)
# Out:
# SVC()

# %% [markdown]
# ## Model evaluation

# %%
y_train_pred = clf.predict(x_train)
y_pred = clf.predict(x_test)

# %%
from sklearn.metrics import accuracy_score, plot_confusion_matrix, plot_roc_curve

# %%
print('Train_accuracy:', accuracy_score(y_train,y_train_pred))
print('Test_accuracy:', accuracy_score(y_test,y_pred))
# Out:
# Train_accuracy: 0.9230769230769231
# Test_accuracy: 0.956140350877193

# %%
plot_confusion_matrix(clf, x_train, y_train, cmap='Blues')

# %%
plot_confusion_matrix(clf, x_test, y_test, cmap='Blues')

# %%
plot_roc_curve(clf, x_test, y_test)

# %% [markdown]
# **The End**
